# %%
# standard library imports
import sys
sys.path.append('..')
# third party imports
import matplotlib.pyplot as plt
# local imports
from functions import random_array, better_array_to_box

# %%
# generate a random array
array = random_array(10,(100,100))
# plot the bounding box form the array
box = better_array_to_box(array)

# %%
fig, ax = plt.subplots(1,2, figsize=(12, 6))
ax[0].imshow(array)
ax[1].imshow(box)
