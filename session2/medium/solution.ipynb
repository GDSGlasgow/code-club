# %%
#standard library imports
import sys
sys.path.append('..')
# third party imports
import matplotlib.pyplot as plt
# local imports
from functions import bounding_box
from easy.functions import generate_points, points_to_array

# %%
# generate some random points
points = generate_points(n=10, array_shape=(100,100))
# plot points on array (for reference)
points_array = points_to_array(points)
# plot bounding box in array
box_array = bounding_box(points, array_shape=(100,100))

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))
ax[0].imshow(points_array)
ax[1].imshow(box_array)
